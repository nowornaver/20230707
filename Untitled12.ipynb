# %% [markdown]
# <a href="https://colab.research.google.com/github/nowornaver/20230707/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @# prompt: 구글 드라이브랑 연결

from google.colab import drive
drive.flush_and_unmount()  # 기존 마운트 해제
drive.mount('/content/drive')  # 다시 마운트
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %pwd
# Out:
# '/content/drive/MyDrive'

# %%
##
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/drive/MyDrive/yolov5

# %%
# !pip install Pillow==10.3
# Out:
# Requirement already satisfied: Pillow==10.3 in /usr/local/lib/python3.10/dist-packages (10.3.0)

# %%
# !mkdir -p Train/labels
# !mkdir -p Train/images
# !mkdir -p Val/labels
# !mkdir -p Val/images

# %%
##검증 데이터 만들기
import os
import shutil
from sklearn.model_selection import train_test_split

def create_validation_set(train_path, val_path, split_ratio=0.3):
    """
    Train 데이터의 일부를 Val로 이동
    """
    # 필요한 디렉토리 생성
    os.makedirs(os.path.join(val_path, 'images'), exist_ok=True)
    os.makedirs(os.path.join(val_path, 'labels'), exist_ok=True)

    # Train 이미지 리스트 가져오기
    train_images = os.listdir(os.path.join(train_path, 'images'))
    train_images = [f for f in train_images if f.endswith(('.jpg', '.jpeg', '.png'))]

    # Train/Val 분할
    _, val_images = train_test_split(train_images,
                                   test_size=split_ratio,
                                   random_state=42)

    # Val로 파일 복사
    for image_file in val_images:
        # 이미지 복사
        src_image = os.path.join(train_path, 'images', image_file)
        dst_image = os.path.join(val_path, 'images', image_file)
        shutil.copy2(src_image, dst_image)

        # 라벨 파일 복사
        label_file = os.path.splitext(image_file)[0] + '.txt'
        src_label = os.path.join(train_path, 'labels', label_file)
        dst_label = os.path.join(val_path, 'labels', label_file)
        if os.path.exists(src_label):
            shutil.copy2(src_label, dst_label)

    print(f"Created validation set with {len(val_images)} images")

# 실행
train_path = '/content/drive/MyDrive/yolov5/Train'
val_path = '/content/drive/MyDrive/yolov5/Val'

create_validation_set(train_path, val_path)
# Out:
# Created validation set with 89 images

# %%
def check_dataset():
    train_path = '/content/drive/MyDrive/yolov5/Train'
    val_path = '/content/drive/MyDrive/yolov5/Val'

    # Train 데이터 확인
    train_images = len(os.listdir(os.path.join(train_path, 'images')))
    train_labels = len(os.listdir(os.path.join(train_path, 'labels')))

    # Val 데이터 확인
    val_images = len(os.listdir(os.path.join(val_path, 'images')))
    val_labels = len(os.listdir(os.path.join(val_path, 'labels')))

    print("Dataset status:")
    print(f"Train - Images: {train_images}, Labels: {train_labels}")
    print(f"Val - Images: {val_images}, Labels: {val_labels}")

# 데이터셋 상태 확인
check_dataset()
# Out:
# Dataset status:
# Train - Images: 294, Labels: 294
# Val - Images: 89, Labels: 89

# %%
#필요 라이브러리 임포트하기
import torch
import os
from IPython.display import Image, clear_output  # to display images

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/yolov5'

# %%
import numpy as np
import tensorflow as tf
import os
from PIL import Image
from tensorflow.python.eager.context import eager_mode

def _preproc(image, output_height=512, output_width=512, resize_side=512):
    ''' imagenet-standard: aspect-preserving resize to 256px smaller-side, then central-crop to 224px'''
    with eager_mode():
        h, w = image.shape[0], image.shape[1]
        scale = tf.cond(tf.less(h, w), lambda: resize_side / h, lambda: resize_side / w)
        resized_image = tf.compat.v1.image.resize_bilinear(tf.expand_dims(image, 0), [int(h*scale), int(w*scale)])
        cropped_image = tf.compat.v1.image.resize_with_crop_or_pad(resized_image, output_height, output_width)
        return tf.squeeze(cropped_image)

def Create_npy(imagespath, imgsize, ext) :
    images_list = [img_name for img_name in os.listdir(imagespath) if
                os.path.splitext(img_name)[1].lower() == '.'+ext.lower()]
    calib_dataset = np.zeros((len(images_list), imgsize, imgsize, 3), dtype=np.float32)

    for idx, img_name in enumerate(sorted(images_list)):
        img_path = os.path.join(imagespath, img_name)
        try:
            # 파일 크기가 정상적인지 확인
            if os.path.getsize(img_path) == 0:
                print(f"Error: {img_path} is empty.")
                continue

            img = Image.open(img_path)
            img = img.convert("RGB")  # RGBA 이미지 등 다른 형식이 있을 경우 강제로 RGB로 변환
            img_np = np.array(img)

            img_preproc = _preproc(img_np, imgsize, imgsize, imgsize)
            calib_dataset[idx,:,:,:] = img_preproc.numpy().astype(np.uint8)
            print(f"Processed image {img_path}")

        except Exception as e:
            print(f"Error processing image {img_path}: {e}")

    np.save('calib_set.npy', calib_dataset)

# %%
#모델 학습하기
# !python train.py  --img 512 --batch 16 --epochs 300 --data /content/drive/MyDrive/yolov5/data.yaml --weights yolov5n.pt --cache
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#                    all        294        575      0.996          1      0.992      0.884
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/19 [00:00<?, ?it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G     0.0166   0.008135          0         44        512:   5% 1/19 [00:00<00:03,  5.12it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01501   0.008407          0         48        512:  11% 2/19 [00:00<00:03,  4.75it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01445   0.008655          0         49        512:  16% 3/19 [00:00<00:04,  3.99it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01451   0.009491          0         58        512:  21% 4/19 [00:01<00:04,  3.56it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01502   0.009092          0         38        512:  26% 5/19 [00:01<00:03,  3.58it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01526   0.009196          0         41        512:  32% 6/19 [00:01<00:03,  3.69it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01539   0.009175          0         48        512:  37% 7/19 [00:01<00:03,  3.60it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01535   0.009361          0         65        512:  42% 8/19 [00:02<00:03,  3.21it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01505   0.009392          0         55        512:  47% 9/19 [00:02<00:02,  3.51it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01516    0.00938          0         49        512:  53% 10/19 [00:02<00:02,  3.81it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01533   0.009577          0         54        512:  58% 11/19 [00:02<00:01,  4.10it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01541   0.009529          0         43        512:  63% 12/19 [00:03<00:01,  3.94it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     184/299      1.56G    0.01529   0.009761          0         60        512:  68% 13/19 [00:03<00:01,  4.22it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     190/299      1.56G    0.01495    0.01063          0         57        512:  84% 16/19 [00:02<00:00,  5.84it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     190/299      1.56G    0.01494    0.01053          0         41        512:  89% 17/19 [00:03<00:00,  5.49it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     190/299      1.56G    0.01484    0.01045          0         52        512:  95% 18/19 [00:03<00:00,  4.78it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     190/299      1.56G    0.01472    0.01041          0         20        512: 100% 19/19 [00:03<00:00,  5.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 10/10 [00:03<00:00,  3.27it/s]
#                    all        294        575      0.996          1      0.992      0.891
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/19 [00:00<?, ?it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     191/299      1.56G     0.0139    0.01069          0         55        512:   5% 1/19 [00:00<00:03,  5.74it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     191/299      1.56G    0.01497    0.01097          0         43        512:  11% 2/19 [00:00<00:03,  4.57it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     191/299      1.56G    0.01516    0.01006          0         44        512:  16% 3/19 [00:00<00:04,  3.59it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     191/299      1.56G    0.01547    0.01035          0         52        512:  21% 4/19 [00:01<00:04,  3.49it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     191/299      1.56G    0.01519    0.01055          0         54        512:  26% 5/19 [00:01<00:04,  3.44it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     191/299      1.56G    0.01454    0.01017          0         49        512:  32% 6/19 [00:01<00:03,  3.30it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     191/299      1.56G    0.01436    0.01026          0         56        512:  37% 7/19 [00:02<00:03,  3.11it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     191/299      1.56G    0.01448   0.009944          0         39        512:  42% 8/19 [00:02<00:03,  3.66it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     191/299      1.56G    0.01429    0.01013          0         61        512:  47% 9/19 [00:02<00:02,  3.85it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
#   with torch.cuda.amp.autocast(amp):
#     297/299      1.56G     0.0124   0.009379          0         53        512:  63% 12/19 [00:03<00:01,  3.52it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     297/299      1.56G    0.01254   0.009425          0         44        512:  68% 13/19 [00:03<00:01,  3.34it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     297/299      1.56G    0.01264   0.009397          0         48        512:  74% 14/19 [00:04<00:01,  3.47it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     297/299      1.56G    0.01241   0.009189          0         42        512:  79% 15/19 [00:04<00:01,  3.56it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     297/299      1.56G     0.0125   0.009219          0         49        512:  84% 16/19 [00:04<00:00,  3.44it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     297/299      1.56G    0.01252   0.009264          0         54        512:  89% 17/19 [00:05<00:00,  3.15it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     297/299      1.56G    0.01252   0.009288          0         59        512:  95% 18/19 [00:05<00:00,  3.54it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     297/299      1.56G    0.01285   0.009528          0         23        512: 100% 19/19 [00:05<00:00,  3.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 10/10 [00:03<00:00,  2.68it/s]
#                    all        294        575      0.996          1      0.993      0.927
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/19 [00:00<?, ?it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01199   0.007411          0         45        512:   5% 1/19 [00:00<00:01,  9.15it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01203   0.008615          0         54        512:  11% 2/19 [00:00<00:02,  8.26it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01286   0.009598          0         56        512:  16% 3/19 [00:00<00:02,  5.45it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01274    0.01027          0         65        512:  21% 4/19 [00:00<00:02,  5.11it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01249    0.01009          0         57        512:  26% 5/19 [00:00<00:02,  5.69it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01283   0.009826          0         48        512:  32% 6/19 [00:01<00:02,  4.85it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01231   0.009365          0         44        512:  37% 7/19 [00:01<00:02,  4.95it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01227   0.009339          0         41        512:  42% 8/19 [00:01<00:02,  4.35it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01255   0.009316          0         52        512:  47% 9/19 [00:01<00:02,  4.83it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01248   0.009263          0         51        512:  53% 10/19 [00:01<00:01,  5.07it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01224   0.009022          0         40        512:  58% 11/19 [00:02<00:01,  4.46it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01223   0.008822          0         41        512:  63% 12/19 [00:02<00:01,  5.12it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01237   0.009024          0         57        512:  68% 13/19 [00:02<00:01,  5.43it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01228   0.008921          0         43        512:  74% 14/19 [00:02<00:01,  4.63it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01227    0.00887          0         43        512:  79% 15/19 [00:03<00:00,  4.48it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01227   0.008684          0         34        512:  84% 16/19 [00:03<00:00,  4.51it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01232   0.008627          0         53        512:  89% 17/19 [00:03<00:00,  5.10it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01232   0.008684          0         55        512:  95% 18/19 [00:03<00:00,  4.91it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     298/299      1.56G    0.01253    0.00891          0         23        512: 100% 19/19 [00:03<00:00,  5.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 10/10 [00:02<00:00,  3.52it/s]
#                    all        294        575      0.996          1      0.993      0.927
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/19 [00:00<?, ?it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01089   0.007701          0         45        512:   5% 1/19 [00:00<00:03,  5.36it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01272   0.007635          0         41        512:  11% 2/19 [00:00<00:04,  4.23it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01251     0.0078          0         45        512:  16% 3/19 [00:00<00:03,  4.07it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01296    0.00793          0         54        512:  21% 4/19 [00:01<00:04,  3.55it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01299   0.008462          0         58        512:  26% 5/19 [00:01<00:04,  3.16it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01255   0.008702          0         60        512:  32% 6/19 [00:01<00:03,  3.43it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01254   0.008638          0         55        512:  37% 7/19 [00:02<00:03,  3.02it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G     0.0126   0.008886          0         58        512:  42% 8/19 [00:02<00:03,  3.04it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G     0.0128   0.008864          0         41        512:  47% 9/19 [00:02<00:03,  3.11it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01281   0.008899          0         56        512:  53% 10/19 [00:03<00:02,  3.09it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01275   0.008832          0         48        512:  58% 11/19 [00:03<00:02,  2.98it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01278   0.008976          0         60        512:  63% 12/19 [00:03<00:02,  3.18it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01269   0.008987          0         52        512:  68% 13/19 [00:03<00:01,  3.44it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G     0.0125   0.008935          0         50        512:  74% 14/19 [00:04<00:01,  3.65it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01243    0.00904          0         61        512:  79% 15/19 [00:04<00:01,  3.30it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01248   0.008958          0         43        512:  84% 16/19 [00:04<00:00,  3.35it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01252   0.009022          0         45        512:  89% 17/19 [00:05<00:00,  3.46it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01249   0.008984          0         52        512:  95% 18/19 [00:05<00:00,  3.20it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     299/299      1.56G    0.01259   0.009105          0         20        512: 100% 19/19 [00:05<00:00,  3.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 10/10 [00:04<00:00,  2.39it/s]
#                    all        294        575      0.996          1      0.993      0.928
#
# 300 epochs completed in 0.719 hours.
# Optimizer stripped from runs/train/exp8/weights/last.pt, 3.8MB
# Optimizer stripped from runs/train/exp8/weights/best.pt, 3.8MB
#
# Validating runs/train/exp8/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 10/10 [00:04<00:00,  2.08it/s]
#                    all        294        575      0.996          1      0.993      0.929
# Results saved to runs/train/exp8

# %%
# !python detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp/weights/best.pt --img 512 --conf 0.1 --source /content/drive/MyDrive/yolov5/Train/03.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/yolov5/Train/03.mp4, data=data/coco128.yaml, imgsz=[512, 512], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-386-g81ac034a Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 29.3ms
# video 1/1 (2/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 9.4ms
# video 1/1 (3/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 11.4ms
# video 1/1 (4/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 10.3ms
# video 1/1 (5/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 10.5ms
# video 1/1 (6/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 9.2ms
# video 1/1 (7/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 10.3ms
# video 1/1 (8/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 10.1ms
# video 1/1 (9/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 8.7ms
# video 1/1 (10/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 8.4ms
# video 1/1 (11/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 10.2ms
# video 1/1 (12/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 16.1ms
# video 1/1 (13/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 8.5ms
# video 1/1 (14/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 8.3ms
# video 1/1 (15/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 10.3ms
# video 1/1 (16/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 8.7ms
# video 1/1 (17/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 9.2ms
# video 1/1 (18/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 9.5ms
# video 1/1 (19/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 10.3ms
# video 1/1 (20/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 10.1ms
# video 1/1 (21/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 7.1ms
# video 1/1 (22/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 8.4ms
# video 1/1 (23/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 10.8ms
# video 1/1 (24/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 9.8ms
# video 1/1 (25/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 11.0ms
# video 1/1 (26/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 10.6ms
# video 1/1 (27/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 2 airpodss, 9.3ms
# video 1/1 (28/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 9.7ms
# video 1/1 (29/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 11.4ms
# video 1/1 (30/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 11.0ms
# video 1/1 (31/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 10.3ms
# video 1/1 (32/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 9.7ms
# video 1/1 (33/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 8.8ms
# video 1/1 (34/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 8.9ms
# video 1/1 (35/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 11.3ms
# video 1/1 (36/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 11.6ms
# video 1/1 (37/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 8.3ms
# video 1/1 (38/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 10.5ms
# video 1/1 (39/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 12.1ms
# video 1/1 (40/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 10.2ms
# video 1/1 (41/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 9.3ms
# video 1/1 (42/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 10.8ms
# video 1/1 (43/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 11.1ms
# video 1/1 (44/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 10.0ms
# video 1/1 (45/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 8.4ms
# video 1/1 (46/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss, 9.3ms
# video 1/1 (47/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 10.6ms
# video 1/1 (48/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 9.7ms
# video 1/1 (49/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 8.2ms
# video 1/1 (50/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 9.9ms
# video 1/1 (51/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 4 airpodss, 11.2ms
# video 1/1 (52/119) /content/drive/MyDrive/yolov5/Train/03.mp4: 512x288 3 airpodss,